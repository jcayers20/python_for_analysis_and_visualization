# %%
# standard imports
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from numpy.random import randn

# stats
from scipy import stats

# plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
url = 'http://en.wikipedia.org/wiki/Histogram'

# %%
data1 = randn(100)

# %%
plt.hist(data1)
# Out:
# (array([ 2.,  3.,  5., 14., 21., 21., 16., 10.,  4.,  4.]),
#  array([-2.58839883, -2.08662705, -1.58485527, -1.08308349, -0.58131171,
#         -0.07953993,  0.42223184,  0.92400362,  1.4257754 ,  1.92754718,
#          2.42931896]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data1, bins = 20)
# Out:
# (array([ 1.,  1.,  1.,  2.,  1.,  4.,  6.,  8., 13.,  8., 10., 11.,  7.,
#          9.,  6.,  4.,  2.,  2.,  2.,  2.]),
#  array([-2.58839883, -2.33751294, -2.08662705, -1.83574116, -1.58485527,
#         -1.33396938, -1.08308349, -0.8321976 , -0.58131171, -0.33042582,
#         -0.07953993,  0.17134595,  0.42223184,  0.67311773,  0.92400362,
#          1.17488951,  1.4257754 ,  1.67666129,  1.92754718,  2.17843307,
#          2.42931896]),
#  <BarContainer object of 20 artists>)

# %%
data2 = randn(80)
plt.hist(data2, color = 'indianred')
# Out:
# (array([ 4.,  5.,  6., 11., 16., 14., 12.,  6.,  3.,  3.]),
#  array([-2.45332887, -1.94514869, -1.4369685 , -0.92878832, -0.42060814,
#          0.08757204,  0.59575223,  1.10393241,  1.61211259,  2.12029277,
#          2.62847296]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data1, density = True, color='indianred', alpha = 0.5, bins = 20)
plt.hist(data2, density = True, alpha = 0.5, bins = 20)
# Out:
# (array([0.0983903 , 0.0983903 , 0.0983903 , 0.14758545, 0.1967806 ,
#         0.0983903 , 0.24597575, 0.2951709 , 0.2951709 , 0.49195149,
#         0.2951709 , 0.3935612 , 0.1967806 , 0.3935612 , 0.1967806 ,
#         0.0983903 , 0.04919515, 0.0983903 , 0.04919515, 0.0983903 ]),
#  array([-2.45332887, -2.19923878, -1.94514869, -1.69105859, -1.4369685 ,
#         -1.18287841, -0.92878832, -0.67469823, -0.42060814, -0.16651805,
#          0.08757204,  0.34166214,  0.59575223,  0.84984232,  1.10393241,
#          1.3580225 ,  1.61211259,  1.86620268,  2.12029277,  2.37438287,
#          2.62847296]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(x = data1, y = data2)

# %%
sns.jointplot(x = data1, y = data2, kind = 'hex')
