# %%
# loading packages
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website='http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#     Rank                       Team      GP   Won   Lost   Tied   Pct.   \
# 0       1         Green Bay Packers   1,386    770    578     38  0.569
# 1       2            Dallas Cowboys     932    527    399      6  0.569
# 2       3          Baltimore Ravens     402    226    175      1  0.563
# 3       4             Chicago Bears   1,434    783    609     42  0.561
# 4       5      New England Patriots     934    520    405      9  0.562
# 5       6            Miami Dolphins     850    468    378      4  0.553
# 6       7         Minnesota Vikings     920    495    414     11  0.544
# 7       8       San Francisco 49ers   1,106    591    499     16  0.542
# 8       9        Kansas City Chiefs     934    496    426     12  0.537
# 9      10       Pittsburgh Steelers   1,222    644    557     21  0.536
# 10     11           New York Giants   1,355    702    620     33  0.530
# 11     12            Denver Broncos     934    490    434     10  0.530
# ...

# %%
nfl_frame.columns = nfl_frame.columns.str.strip()
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'Season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame.Team
# Out:
# 0            Green Bay Packers
# 1               Dallas Cowboys
# 2             Baltimore Ravens
# 3                Chicago Bears
# 4         New England Patriots
# 5               Miami Dolphins
# 6            Minnesota Vikings
# 7          San Francisco 49ers
# 8           Kansas City Chiefs
# 9          Pittsburgh Steelers
# 10             New York Giants
# 11              Denver Broncos
# 12       Indianapolis Colts[d]
# 13           Las Vegas Raiders
# 14            Seattle Seahawks
# 15            Los Angeles Rams
# 16    Washington Football Team
# 17        Los Angeles Chargers
# 18         Cleveland Browns[e]
# 19         Philadelphia Eagles
# 20            Tennessee Titans
# 21           Carolina Panthers
# 22               Buffalo Bills
# 23          New Orleans Saints
# 24               Detroit Lions
# 25          Cincinnati Bengals
# 26               New York Jets
# 27              Houston Texans
# 28             Atlanta Falcons
# 29           Arizona Cardinals
# ...

# %%
nfl_frame['Division']
# Out:
# 0     NFC North
# 1      NFC East
# 2     AFC North
# 3     NFC North
# 4      AFC East
# 5      AFC East
# 6     NFC North
# 7      NFC West
# 8      AFC West
# 9     AFC North
# 10     NFC East
# 11     AFC West
# 12    AFC South
# 13     AFC West
# 14     NFC West
# 15     NFC West
# 16     NFC East
# 17     AFC West
# 18    AFC North
# 19     NFC East
# 20    AFC South
# 21    NFC South
# 22     AFC East
# 23    NFC South
# 24    NFC North
# 25    AFC North
# 26     AFC East
# 27    AFC South
# 28    NFC South
# 29     NFC West
# 30    AFC South
# 31    NFC South
# Name: Division, dtype: object

# %%
nfl2 = DataFrame(nfl_frame, columns = ['Team', 'Division', 'Stadium'])

# %%
nfl2.Stadium.dtype
# Out:
# dtype('float64')

# %%
nfl2.head()
# Out:
#                     Team   Division  Stadium
# 0     Green Bay Packers   NFC North      NaN
# 1        Dallas Cowboys    NFC East      NaN
# 2      Baltimore Ravens   AFC North      NaN
# 3         Chicago Bears   NFC North      NaN
# 4  New England Patriots    AFC East      NaN

# %%
nfl2.tail(10)
# Out:
#                      Team   Division  Stadium
# 22         Buffalo Bills    AFC East      NaN
# 23    New Orleans Saints   NFC South      NaN
# 24         Detroit Lions   NFC North      NaN
# 25    Cincinnati Bengals   AFC North      NaN
# 26         New York Jets    AFC East      NaN
# 27        Houston Texans   AFC South      NaN
# 28       Atlanta Falcons   NFC South      NaN
# 29     Arizona Cardinals    NFC West      NaN
# 30  Jacksonville Jaguars   AFC South      NaN
# 31  Tampa Bay Buccaneers   NFC South      NaN

# %%
nfl_frame.loc[3]
# Out:
# Rank                     4
# Team        Chicago Bears
# GP                  1,434
# Won                    783
# Lost                   609
# Tied                    42
# Pct.                 0.561
# Season                1920
# Division         NFC North
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame['Stadium'] = np.arange(0, 32)

# %%
stadiums = Series(["Lambeau Field", "AT&T Stadium", "M&T Bank Stadium", "Soldier Field", "Gillette Stadium"])

# %%
nfl_frame['Stadium'] = stadiums

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#     Rank                       Team      GP  Won  Lost  Tied   Pct.  Season  \
# 0      1         Green Bay Packers   1,386   770   578    38  0.569    1921
# 1      2            Dallas Cowboys     932   527   399     6  0.569    1960
# 2      3          Baltimore Ravens     402   226   175     1  0.563    1996
# 3      4             Chicago Bears   1,434   783   609    42  0.561    1920
# 4      5      New England Patriots     934   520   405     9  0.562    1960
# 5      6            Miami Dolphins     850   468   378     4  0.553    1966
# 6      7         Minnesota Vikings     920   495   414    11  0.544    1961
# 7      8       San Francisco 49ers   1,106   591   499    16  0.542    1950
# 8      9        Kansas City Chiefs     934   496   426    12  0.537    1960
# 9     10       Pittsburgh Steelers   1,222   644   557    21  0.536    1933
# 10    11           New York Giants   1,355   702   620    33  0.530    1925
# ...

# %%
data = {'City': ['SF', 'LA', 'NYC'], 'Population': [837000,3880000,8400000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 3880000, 8400000]}

# %%
city_frame = DataFarm
